# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, accuracy_score, precision_score, recall_score, f1_score
from imblearn.over_sampling import SMOTE  # For handling class imbalance

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

#Set random seed
np.random.seed(42)

# %%
#Load data
data = pd.read_csv("match_data_v5.csv")

#Name columns
data.columns = ["matchID", "blueTeamControlWardsPlaced", "blueTeamWardsPlaced", "blueTeamTotalKills", 
                "blueTeamDragonKills", "blueTeamHeraldKills", "blueTeamTowersDestroyed", 
                "blueTeamInhibitorsDestroyed", "blueTeamTurretPlatesDestroyed", "blueTeamFirstBlood", 
                "blueTeamMinionsKilled", "blueTeamJungleMinions", "blueTeamTotalGold", "blueTeamXp", 
                "blueTeamTotalDamageToChamps", "redTeamControlWardsPlaced", "redTeamWardsPlaced", 
                "redTeamTotalKills", "redTeamDragonKills", "redTeamHeraldKills", "redTeamTowersDestroyed", 
                "redTeamInhibitorsDestroyed", "redTeamTurretPlatesDestroyed", "redTeamMinionsKilled", 
                "redTeamJungleMinions", "redTeamTotalGold", "redTeamXp", "redTeamTotalDamageToChamps", 
                "blueWin", "empty"]


#Drop unnecessary columns
data = data.drop(columns=['matchID', 'empty'])
data = data.dropna()

#Feature Engineering
data['totalKills'] = data['blueTeamTotalKills'] + data['redTeamTotalKills']
data['goldDiff'] = data['blueTeamTotalGold'] - data['redTeamTotalGold']
data['xpDiff'] = data['blueTeamXp'] - data['redTeamXp']
data['dragonDiff'] = data['blueTeamDragonKills'] - data['redTeamDragonKills']
data['heraldDiff'] = data['blueTeamHeraldKills'] - data['redTeamHeraldKills']
data['towerDiff'] = data['blueTeamTowersDestroyed'] - data['redTeamTowersDestroyed']
data['inhibitorDiff'] = data['blueTeamInhibitorsDestroyed'] - data['redTeamInhibitorsDestroyed']
data['turretPlateDiff'] = data['blueTeamTurretPlatesDestroyed'] - data['redTeamTurretPlatesDestroyed']
data['minionDiff'] = data['blueTeamMinionsKilled'] - data['redTeamMinionsKilled']
data['jungleMinionDiff'] = data['blueTeamJungleMinions'] - data['redTeamJungleMinions']
data['damageDiff'] = data['blueTeamTotalDamageToChamps'] - data['redTeamTotalDamageToChamps']
data['firstBlood'] = data['blueTeamFirstBlood'].astype(int)

#Select relevant features
features = ['goldDiff', 'xpDiff', 'dragonDiff', 'heraldDiff', 'towerDiff',
            'inhibitorDiff', 'turretPlateDiff', 'minionDiff', 'jungleMinionDiff',
            'damageDiff', 'firstBlood']

X = data[features]
y = data['blueWin'].astype(int)

#Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

#Handle imbalance with SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

#Feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_resampled)
X_test_scaled = scaler.transform(X_test)

# %%
#seq model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy', 'Precision', 'Recall'])

#Define callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

#Train model
history = model.fit(
    X_train_scaled,
    y_train_resampled,
    epochs=100,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stop, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - Precision: 0.6362 - Recall: 0.7746 - accuracy: 0.6622 - loss: 0.6352 - val_Precision: 0.8247 - val_Recall: 0.6942 - val_accuracy: 0.7594 - val_loss: 0.5019 - learning_rate: 0.0010
# Epoch 2/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7304 - Recall: 0.7193 - accuracy: 0.7316 - loss: 0.5256 - val_Precision: 0.8178 - val_Recall: 0.7274 - val_accuracy: 0.7693 - val_loss: 0.4864 - learning_rate: 0.0010
# Epoch 3/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7528 - Recall: 0.7227 - accuracy: 0.7447 - loss: 0.5069 - val_Precision: 0.8261 - val_Recall: 0.7082 - val_accuracy: 0.7660 - val_loss: 0.4889 - learning_rate: 0.0010
# Epoch 4/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7506 - Recall: 0.7262 - accuracy: 0.7442 - loss: 0.5100 - val_Precision: 0.8141 - val_Recall: 0.7308 - val_accuracy: 0.7686 - val_loss: 0.4812 - learning_rate: 0.0010
# Epoch 5/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7609 - Recall: 0.7274 - accuracy: 0.7518 - loss: 0.4999 - val_Precision: 0.8039 - val_Recall: 0.7490 - val_accuracy: 0.7698 - val_loss: 0.4817 - learning_rate: 0.0010
# Epoch 6/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7411 - Recall: 0.7350 - accuracy: 0.7447 - loss: 0.5038 - val_Precision: 0.7932 - val_Recall: 0.7798 - val_accuracy: 0.7752 - val_loss: 0.4795 - learning_rate: 0.0010
# Epoch 7/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Precision: 0.7473 - Recall: 0.7501 - accuracy: 0.7493 - loss: 0.5020 - val_Precision: 0.7976 - val_Recall: 0.7692 - val_accuracy: 0.7739 - val_loss: 0.4840 - learning_rate: 0.0010
# Epoch 8/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7474 - Recall: 0.7377 - accuracy: 0.7502 - loss: 0.5029 - val_Precision: 0.8009 - val_Recall: 0.7678 - val_accuracy: 0.7755 - val_loss: 0.4747 - learning_rate: 0.0010
# Epoch 9/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.7430 - Recall: 0.7361 - accuracy: 0.7457 - loss: 0.5056 - val_Precision: 0.8032 - val_Recall: 0.7635 - val_accuracy: 0.7752 - val_loss: 0.4786 - learning_rate: 0.0010
# Epoch 10/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7378 - Recall: 0.7424 - accuracy: 0.7439 - loss: 0.5044 - val_Precision: 0.8122 - val_Recall: 0.7466 - val_accuracy: 0.7739 - val_loss: 0.4821 - learning_rate: 0.0010
# Epoch 11/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7570 - Recall: 0.7270 - accuracy: 0.7522 - loss: 0.4960 - val_Precision: 0.7949 - val_Recall: 0.7731 - val_accuracy: 0.7737 - val_loss: 0.4781 - learning_rate: 0.0010
# Epoch 12/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7563 - Recall: 0.7439 - accuracy: 0.7546 - loss: 0.4984 - val_Precision: 0.7999 - val_Recall: 0.7630 - val_accuracy: 0.7729 - val_loss: 0.4757 - learning_rate: 0.0010
# Epoch 13/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7516 - Recall: 0.7362 - accuracy: 0.7503 - loss: 0.4954 - val_Precision: 0.8002 - val_Recall: 0.7644 - val_accuracy: 0.7737 - val_loss: 0.4767 - learning_rate: 0.0010
# Epoch 14/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7506 - Recall: 0.7458 - accuracy: 0.7516 - loss: 0.4975 - val_Precision: 0.8019 - val_Recall: 0.7611 - val_accuracy: 0.7734 - val_loss: 0.4770 - learning_rate: 5.0000e-04
# Epoch 15/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7458 - Recall: 0.7372 - accuracy: 0.7498 - loss: 0.4971 - val_Precision: 0.8016 - val_Recall: 0.7654 - val_accuracy: 0.7749 - val_loss: 0.4776 - learning_rate: 5.0000e-04
# Epoch 16/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7521 - Recall: 0.7345 - accuracy: 0.7517 - loss: 0.4954 - val_Precision: 0.8035 - val_Recall: 0.7567 - val_accuracy: 0.7726 - val_loss: 0.4767 - learning_rate: 5.0000e-04
# Epoch 17/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.7585 - Recall: 0.7432 - accuracy: 0.7549 - loss: 0.4946 - val_Precision: 0.8104 - val_Recall: 0.7437 - val_accuracy: 0.7716 - val_loss: 0.4785 - learning_rate: 5.0000e-04
# Epoch 18/100
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Precision: 0.7540 - Recall: 0.7276 - accuracy: 0.7503 - loss: 0.4977 - val_Precision: 0.8070 - val_Recall: 0.7476 - val_accuracy: 0.7711 - val_loss: 0.4774 - learning_rate: 5.0000e-04

# %%
#Load the best model
model.load_weights('best_model.keras')

#Predict on test data
y_pred_probs = model.predict(X_test_scaled)
y_pred = (y_pred_probs > 0.5).astype(int)

#Compute evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_probs)

print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test F1-Score: {f1:.4f}")
print(f"Test ROC-AUC Score: {roc_auc:.4f}")

#Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

#Plot training history
plt.figure(figsize=(12, 4))

#Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

#Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Test Accuracy: 0.7616
# Test Precision: 0.7723
# Test Recall: 0.7346
# Test F1-Score: 0.7529
# Test ROC-AUC Score: 0.8426
